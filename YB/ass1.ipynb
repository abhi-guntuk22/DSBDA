# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/dataset_Facebook.csv",delimiter=';')

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df=df.dropna()

# %%
#subset data

# %%
df_sub1=df[['Type','Category','comment','like']]

# %%
df_sub1.head()
# Out:
#      Type  Category  comment    like
# 0   Photo         2        4    79.0
# 1  Status         2        5   130.0
# 2   Photo         3        0    66.0
# 3   Photo         2       58  1572.0
# 4   Photo         2       19   325.0

# %%
df_sub2=df[(df['like']>100) & (df['comment']>20)]

# %%
df_sub2[['Type','like','comment']].head()
# Out:
#       Type    like  comment
# 3    Photo  1572.0       58
# 28   Photo   523.0       36
# 30   Photo   107.0       33
# 51   Photo   285.0       24
# 101  Photo  1505.0       26

# %%
df_sub3=df[(df['Type']=='Video') | (df['Type']=='Photo')]
df_sub3.head()
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441  Photo         2          12             4          3
# 2            139441  Photo         3          12             3          3
# 3            139441  Photo         2          12             2         10
# 4            139441  Photo         2          12             2          3
# 6            139441  Photo         3          12             1          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# 6   1.0                      11692                            19479
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# ...

# %%
#merge data

# %%
df_1=df[['Type','like','share']]
df_2=df[['Type','comment']]
df_merge=pd.merge(df_1,df_2,on='Type')

# %%
df_merge.head()
# Out:
#     Type  like  share  comment
# 0  Photo  79.0   17.0        4
# 1  Photo  79.0   17.0        0
# 2  Photo  79.0   17.0       58
# 3  Photo  79.0   17.0       19
# 4  Photo  79.0   17.0        3

# %%
#sorting

# %%
df_desc=df.sort_values(by='like',ascending=False)
df_desc.head()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 379            111620  Photo         3           4             1         14
# 349            117764  Photo         3           5             5         13
# 168            135428  Photo         1           9             3         10
# 3              139441  Photo         2          12             2         10
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 244   1.0                     180480                           319133
# 379   1.0                     105632                           147918
# 349   0.0                      81856                           124753
# 168   0.0                      41984                            68290
# 3     1.0                      50128                            87991
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df_asc=df.sort_values(by='comment',ascending=True)
df_asc.head()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 496             81370  Photo         2           1             5          8
# 492             85979   Link         1           1             5         11
# 2              139441  Photo         3          12             3          3
# 23             138414  Photo         3          12             7          3
# 22             138414   Link         1          12             7         10
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 496   0.0                       3480                             6229
# 492   0.0                      45920                             5808
# 2     0.0                       2413                             4373
# 23    0.0                       2723                             4888
# 22    0.0                       3454                             6853
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
#transpose

# %%
df_t=df.T
df_t.head()
# Out:
#                      0       1       2       3       4       5       6    \
# Page total likes  139441  139441  139441  139441  139441  139441  139441
# Type               Photo  Status   Photo   Photo   Photo  Status   Photo
# Category               2       2       3       2       2       2       3
# Post Month            12      12      12      12      12      12      12
# Post Weekday           4       3       3       2       2       1       1
#
#                      7       8       9    ...    489    490    491    492  \
# Page total likes  139441  139441  139441  ...  85979  85979  85979  85979
# Type               Photo  Status   Photo  ...  Photo  Photo  Photo   Link
# Category               3       2       3  ...      3      3      3      1
# Post Month            12      12      12  ...      1      1      1      1
# Post Weekday           7       7       6  ...      7      6      6      5
#
#                     493    494    495    496    497    498
# ...

# %%
#shape reshape

# %%
df.shape
# Out:
# (495, 19)

# %%
df_pivo=pd.pivot_table(df,index='Type',columns='Category',values='comment')
df_pivo
# Out:
# Category          1          2         3
# Type
# Link       2.900000   2.000000  2.000000
# Photo      6.027624  11.822222  6.913333
# Status     4.333333   9.921053  2.750000
# Video     12.285714        NaN       NaN

# %%
df['Category'].value_counts()
# Out:
# Category
# 1    211
# 3    155
# 2    129
# Name: count, dtype: int64

# %%
reshape_df = pd.melt(
    df[['Type', 'Category', 'share']],
    id_vars=['Type'],
    var_name='Attribute',
    value_name='Value'
)

# %%
reshape_df.head()
# Out:
#      Type Attribute  Value
# 0   Photo  Category    2.0
# 1  Status  Category    2.0
# 2   Photo  Category    3.0
# 3   Photo  Category    2.0
# 4   Photo  Category    2.0
